# %% [markdown]
# <h1>Import Libraries</h1>

# %% [markdown]
# <p1>Lets first import the required libraries.</p1>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <H1>Simple Test</H1>
# Lets do a simple test to validate our environment.

# %%
print("Hello Hello Capstone Project Course!")
# Out:
# Hello Hello Capstone Project Course!
